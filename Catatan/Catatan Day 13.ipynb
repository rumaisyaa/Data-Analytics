# %% [markdown]
# #Machine Learning

# %% [markdown]
# Machine Learning adalah suatu mesin untuk belajar dengan sendirinya. Machine learning terdiri dari tiga yaitu unsupervised, superviced (paling sering digunakan di Indonesia), reinforcement(Paling jarang digunakan contohnya = alphago).
#
# Superviced learning = input data yang disebut sebagai training data yang ada labelnya
#
# Unsupervised learning = ada data tetapi tidak ada labelnya
#
# ![image.png](data:image/png;base64,...)
#
# Output unsupervised = clustering (kelompok)
#
# Output Supervised = model predictive dan hasilnya hanya 1.

# %% [markdown]
# ##Supervised Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jenis Supervised
#
# 1. Classification = mengelompokan (berupa kategori contoh diterima / ditolak, high/low)
#
# 2. Regression = identik dengan numerik (kontinu / banyak data numeriknya)
#
# ![image.png](data:image/png;base64,...)
#
# Jika classification menggunakan data kategory (label categorical)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Regression

# %% [markdown]
# Regresi mengambil suatu variabel yang random (beta 0) untuk memprediksi kejadian yang belum tau jawabannya / secara matematik untuk mencari hubungan antara keduanya.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Linear Regression
#
# ![image.png](data:image/png;base64,...)
#
# Mencari error/kesalahan dari intuisinya karena ingin memprediksi dan mencari error seminimal itu.

# %% [markdown]
# ##Contoh Linear Rergresion
#
# ![image.png](data:image/png;base64,...)
#
# Untuk menentukan berapa sizenya ketika berat badannya sekian.
#
# ![image.png](data:image/png;base64,...)
#
# Untuk menentukan hal tersebut maka dibuatlah garis melintang dan banyak kandidatnya secara randomly dan dipilih garis yang terbaik. Kemudian setiap garis tersebut akan dicari errornya.
#
# ![image.png](data:image/png;base64,...)
#
# Setelah dilakukan looping dalam penentuan garis dan errornya selanjutnya dipilih yang errornya paling kecil dan kandidat garis yang paling optimal sebagai contoh gambar diatas.

# %% [markdown]
# #HANDS ON

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# train.csv -> split -> train dan val
# test.csv -> tidak memiliki label -> label hasil pred -> peringkat


# train.csv ->  split -> train dan test

# %%
data = pd.read_csv('/content/drive/MyDrive/Bimbing/Zenius - Kampus Merdeka/Statistical Modeling I (Supervised Learning - Regression)/Advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
data = data[['TV','Sales']]
data.head(3)
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.scatterplot(x='TV', y='Sales', data=data, s=70)

title = 'Sales and TV'
ax.text(45,26,title,horizontalalignment='center',color='#800000',fontsize=20,fontweight='bold')

ax.set_xlabel('Television', fontsize=15, color='#800000')
ax.set_ylabel('Sales', fontsize=14, color='#800000')
# Out:
# Text(0, 0.5, 'Sales')

# %%
data.columns = ['x','y']
data.head()
# Out:
#        x     y
# 0  230.1  22.1
# 1   44.5  10.4
# 2   17.2   9.3
# 3  151.5  18.5
# 4  180.8  12.9

# %%
data['(x-x_mean)'] = round(data['x'] - data['x'].mean(),2)
data['(y-y_mean)'] = round(data['y'] - data['y'].mean(),2)
data['(x-x_mean)(y-y_mean)'] = data['(x-x_mean)'] * data['(y-y_mean)']
data['pow((x-x_mean),2)'] = round(pow(data['x'] - data['x'].mean(),2),2)
data.head()
# Out:
#        x     y  (x-x_mean)  (y-y_mean)  (x-x_mean)(y-y_mean)  \
# 0  230.1  22.1       83.06        8.08              671.1248
# 1   44.5  10.4     -102.54       -3.62              371.1948
# 2   17.2   9.3     -129.84       -4.72              612.8448
# 3  151.5  18.5        4.46        4.48               19.9808
# 4  180.8  12.9       33.76       -1.12              -37.8112
#
#    pow((x-x_mean),2)
# 0            6898.55
# 1           10514.96
# 2           16859.07
# 3              19.87
# 4            1139.57

# %%
b1 = data['(x-x_mean)(y-y_mean)'].sum() / data['pow((x-x_mean),2)'].sum()
b1
# Out:
# 0.047536644161412324

# %%
b0 = data['y'].mean() - b1 * data['x'].mean()
b0
# Out:
# 7.032593000895529

# %%
textstr = 'y = '+str(b0)+' + '+str(b1)+' * x'
textstr
# Out:
# 'y = 7.032593000895529 + 0.047536644161412324 * x'

# %%
data['y_pred'] = b0 + b1*data['x']
data.head()
# Out:
#        x     y  (x-x_mean)  (y-y_mean)  (x-x_mean)(y-y_mean)  \
# 0  230.1  22.1       83.06        8.08              671.1248
# 1   44.5  10.4     -102.54       -3.62              371.1948
# 2   17.2   9.3     -129.84       -4.72              612.8448
# 3  151.5  18.5        4.46        4.48               19.9808
# 4  180.8  12.9       33.76       -1.12              -37.8112
#
#    pow((x-x_mean),2)     y_pred
# 0            6898.55  17.970775
# 1           10514.96   9.147974
# 2           16859.07   7.850223
# 3              19.87  14.234395
# 4            1139.57  15.627218

# %%
from sklearn.linear_model import LinearRegression

x = data.x.values.reshape(-1,1)
y = data.y.values.reshape(-1,1)

X_train, X_test,Y_train,Y_test = train_test_split(X_std,y,
                                                test_size = 0.4,
                                                random_state = 42)

model = LinearRegression().fit(X_train, Y_train)

b0 = float(model.intercept_[0])
b0 = round(b0,3)
b1 = float(model.coef_[0][0])
b1 = round(b1,3)
print('intercept (b0 ): ', b0)
print('slope (b1) : ', b1)
print(' ')
textstr = 'y = '+str(b0)+' + '+str(b1)+' * x'
print(textstr)
# Out:
# intercept (b0 ):  7.033
# slope (b1) :  0.048
#
# y = 7.033 + 0.048 * x

# %%
y[0:3]
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3]])

# %%
y_pred = model.predict(X_test)
y_pred[0:3]
# Out:
# array([[17.97077451],
#        [ 9.14797405],
#        [ 7.85022376]])

# %%
from sklearn.metrics import r2_score

print('R-squared for training data is {}'.format(r2_score(y_pred, y)))
# Out:
# R-squared for training data is 0.36567940037641455

# %%
from sklearn.metrics import mean_squared_error

print('RMSE for testing data is {}'.format(np.sqrt(mean_squared_error(y_pred, Y_test))))
# Out:
# RMSE for testing data is 3.2423221486546887

# %%
from sklearn.metrics import mean_absolute_error

print('MAE for training data is {}'.format(mean_absolute_error(y_pred, y)))
# Out:
# MAE for training data is 2.549806038927486

# %%
# dalam memprediksi itu error +- 2.5

# prediksi 15 -> 12.5 atau 17.5
# acceptable menurut atasan?
# deploy , re-modeling

# %%
data.describe()
# Out:
#                 x           y
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
textstr
# Out:
# 'y = 7.032593000895529 + 0.047536644161412324 * x'

# %%
fit = np.polyfit(data['x'], data['y'], deg=1)
y_hat = fit[1] + data['x'] * fit[0]

fig, ax = plt.subplots(figsize=(7,5))
sns.regplot(x='x', y='y', data=data)
plt.vlines(data['x'], y_hat, data['y'], lw = .4, colors='r');

title = 'Sales and TV'
ax.text(40,26,title,horizontalalignment='center',color='#800000',fontsize=14,fontweight='bold')
ax.text(46,24,textstr,horizontalalignment='center',color='#800000',fontsize=8,fontweight='bold')
ax.set_xlabel('Television', fontsize=10, color='#800000')
ax.set_ylabel('Sales', fontsize=8, color='#800000')
# Out:
# Text(0, 0.5, 'Sales')

# %%
data = pd.read_csv('/content/drive/MyDrive/Bimbing/Zenius - Kampus Merdeka/Statistical Modeling I (Supervised Learning - Regression)/Advertising.csv')
data = data[['TV','Radio','Sales']]
data.head()
# Out:
#       TV  Radio  Sales
# 0  230.1   37.8   22.1
# 1   44.5   39.3   10.4
# 2   17.2   45.9    9.3
# 3  151.5   41.3   18.5
# 4  180.8   10.8   12.9

# %%
x = data[['TV','Radio']]
y = data['Sales']

model = LinearRegression().fit(x, y)

# %%
b0 = round(float(model.intercept_),3)
b1 = round(float(model.coef_[0]),3)
b2 = round(float(model.coef_[1]),3)
print('intercept (b0 ) : ', b0)
print('slope (b1)      : ', b1)
print('slope (b2)      : ', b2)
print(' ')
textstr = 'y = '+str(b0)+' + '+str(b1)+' * TV  + '+str(b2)+' * Radio'
print(textstr)
# Out:
# intercept (b0 ) :  2.921
# slope (b1)      :  0.046
# slope (b2)      :  0.188
#
# y = 2.921 + 0.046 * TV  + 0.188 * Radio

# %%
data = pd.read_csv('/content/drive/MyDrive/Bimbing/Zenius - Kampus Merdeka/Statistical Modeling I (Supervised Learning - Regression)/Advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
x = data[['TV','Radio','Newspaper']]
y = data['Sales']

model = LinearRegression().fit(x, y)

# %%
b0 = round(float(model.intercept_),3)
b1 = round(float(model.coef_[0]),3)
b2 = round(float(model.coef_[1]),3)
b3 = round(float(model.coef_[2]),3)
print('intercept (b0 ) : ', b0)
print('slope (b1)      : ', b1)
print('slope (b2)      : ', b2)
print('slope (b3)      : ', b3)
print(' ')
textstr = 'y = '+str(b0)+' + '+str(b1)+' * TV  + '+str(b2)+' * Radio' 
print(textstr)
# Out:
# intercept (b0 ) :  2.939
# slope (b1)      :  0.046
# slope (b2)      :  0.189
# slope (b3)      :  -0.001
#
# y = 2.939 + 0.046 * TV  + 0.189 * Radio
