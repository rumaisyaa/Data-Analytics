# %% [markdown]
# # JOIN OPERATION in SQL

# %% [markdown]
# #JOIN
#
# Untuk mengkombine/ menggabungkan data dari banyaknya table berdasarkan kondisi kecocokan antar tabel data

# %% [markdown]
# ## TIPE JOIN
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##INNER JOIN

# %% [markdown]
# perintah yang digunakan untuk menampilkan sebuah data atau record dengan menghubungkan dua table atau lebih dalam satu perintah
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## LEFT JOIN
# semua data pada tabel sebelah kiri akan ditampilkan, sedangkan data pada tabel disebelah kanan hanya akan ditampilkan jika data terkait pada tabel tersebut muncul di tabel sebelah kiri.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## RIGHT JOIN
#
# data pada tabel sebelah kanan akan ditampilkan semua, sedangkan data pada sebelah kiri hanya ditampilkan jika data terkait pada tabel tersebut muncul pada tabel sebelah kanan
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##FULL / OUTER JOIN
#
# Menggabungkan record kanan dan kiri
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #JOIN Syntax
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MINI PRACTICE

# %% [markdown]
# ##Jawaban NO 1
#
# Semua CustomerName dari setiap order yang ada
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Jawaban No 4
#
# Top 3 CustomerName dengan Order terbanyak
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #UNION

# %% [markdown]
# UNION menggabungkan table tapi akan menggabungkan rowsnya
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Subquery
#
# Membuat query didalam query
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #CTE
# CTE membuat semacam temporary table
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #HANDS ON SQL

# %% [markdown]
# ##Join

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SubQuery

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##CTE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MINI PRACTICE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #1.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.
#
# ![image.png](data:image/png;base64,...)
